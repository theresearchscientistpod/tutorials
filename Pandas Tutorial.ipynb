# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(5))
s
# Out:
# 0    0.883452
# 1    0.136827
# 2   -1.187359
# 3    0.747463
# 4   -1.696055
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), index=['v', 'w', 'x', 'y', 'z'])
s
# Out:
# v    2.435779
# w   -0.809379
# x    0.438789
# y    0.121943
# z   -1.101200
# dtype: float64

# %%
#Conditional Selection Using Numerical Values
df = pd.read_csv('data/netflix_titles.csv', index_col='title')
country = df['country']
most_common_country = country.mode()
print(most_common_country[0])
country.fillna(most_common_country[0], inplace=True)
df.isnull().sum()
# Out:
# United States
# show_id            0
# type               0
# director        1969
# cast             570
# country            0
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df = pd.read_csv('data/netflix_titles.csv', index_col='title')
df
# Out:
#                                               show_id     type  \
# title
# Norm of the North: King Sized Adventure      81145628    Movie
# Jandino: Whatever it Takes                   80117401    Movie
# Transformers Prime                           70234439  TV Show
# Transformers: Robots in Disguise             80058654  TV Show
# #realityhigh                                 80125979    Movie
# ...                                               ...      ...
# Red vs. Blue                                 80000063  TV Show
# Maron                                        70286564  TV Show
# Little Baby Bum: Nursery Rhyme Friends       80116008    Movie
# A Young Doctor's Notebook and Other Stories  70281022  TV Show
# Friends                                      70153404  TV Show
#
#                                                              director  \
# title
# Norm of the North: King Sized Adventure      Richard Finn, Tim Maltby
# ...

# %%
import sqlite3
conn = sqlite3.connect('data/netflix_titles.db')
df.to_sql('films', con=conn)

# %%
conn = sqlite3.connect('data/netflix_titles.db')
conn.execute("SELECT * from films limit 2").fetchall()

df_db = pd.read_sql_query("select * from films;", conn)
df_db.head()
# Out:
#                                      title   show_id     type  \
# 0  Norm of the North: King Sized Adventure  81145628    Movie
# 1               Jandino: Whatever it Takes  80117401    Movie
# 2                       Transformers Prime  70234439  TV Show
# 3         Transformers: Robots in Disguise  80058654  TV Show
# 4                             #realityhigh  80125979    Movie
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                      None
# 2                      None
# 3                      None
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
#Read from JSON
df = pd.read_json('data/netflix_titles.json')
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                         None
# 2                         None
# ...

# %%
df = pd.read_excel('data/netflix_titles.xls')
df
# Out:
#       Unnamed: 0   show_id     type  \
# 0              0  81145628    Movie
# 1              1  80117401    Movie
# 2              2  70234439  TV Show
# 3              3  80058654  TV Show
# 4              4  80125979    Movie
# ...          ...       ...      ...
# 6229        6229  80000063  TV Show
# 6230        6230  70286564  TV Show
# 6231        6231  80116008    Movie
# 6232        6232  70281022  TV Show
# 6233        6233  70153404  TV Show
#
#                                             title                  director  \
# 0         Norm of the North: King Sized Adventure  Richard Finn, Tim Maltby
# 1                      Jandino: Whatever it Takes                       NaN
# 2                              Transformers Prime                       NaN
# 3                Transformers: Robots in Disguise                       NaN
# 4                                    #realityhigh          Fernando Lebrija
# ...

# %%
data = {
    'strawberries':[4, 5, 5, 3, 1],
    'mushrooms':[0, 0, 3, 4, 6]
}

stock = pd.DataFrame(data)
stock
# Out:
#    strawberries  mushrooms
# 0             4          0
# 1             5          0
# 2             5          3
# 3             3          4
# 4             1          6

# %%
stock = pd.DataFrame(data, index=['June', 'July', 'August', 'September', 'October'])
stock
# Out:
#            strawberries  mushrooms
# June                  4          0
# July                  5          0
# August                5          3
# September             3          4
# October               1          6

# %%
stock.loc['August']
# Out:
# strawberries    5
# mushrooms       3
# Name: August, dtype: int64

# %%
stock.shape
# Out:
# (5, 2)

# %%
import sqlite3
conn = sqlite3.connect('data/flights.db')

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM AIRLINES limit 5;")
results = cur.fetchall()
results
# Out:
# [(0, '1', 'Private flight', '\\N', '-', None, None, None, 'Y'),
#  (1, '2', '135 Airways', '\\N', None, 'GNL', 'GENERAL', 'United States', 'N'),
#  (2, '3', '1Time Airline', '\\N', '1T', 'RNX', 'NEXTIME', 'South Africa', 'Y'),
#  (3,
#   '4',
#   '2 Sqn No 1 Elementary Flying Training School',
#   '\\N',
#   None,
#   'WYT',
#   None,
#   'United Kingdom',
#   'N'),
#  (4, '5', '213 Flight Unit', '\\N', None, 'TFU', None, 'Russia', 'N')]

# %%
df_db = pd.read_sql_query("select * from airlines limit 5;", conn)
df_db['country']
# Out:
# 0              None
# 1     United States
# 2      South Africa
# 3    United Kingdom
# 4            Russia
# Name: country, dtype: object

# %%
#Get the top lines of your dataset
df.head()
# Out:
#    Unnamed: 0   show_id     type                                    title  \
# 0           0  81145628    Movie  Norm of the North: King Sized Adventure
# 1           1  80117401    Movie               Jandino: Whatever it Takes
# 2           2  70234439  TV Show                       Transformers Prime
# 3           3  80058654  TV Show         Transformers: Robots in Disguise
# 4           4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
# ...

# %%
#Show botttom 10 rows of dataset
df.tail(10)
# Out:
#       Unnamed: 0   show_id     type  \
# 6224        6224  70304979  TV Show
# 6225        6225  70153412  TV Show
# 6226        6226  70243132  TV Show
# 6227        6227  80005756  TV Show
# 6228        6228  80159925  TV Show
# 6229        6229  80000063  TV Show
# 6230        6230  70286564  TV Show
# 6231        6231  80116008    Movie
# 6232        6232  70281022  TV Show
# 6233        6233  70153404  TV Show
#
#                                             title director  \
# 6224              Anthony Bourdain: Parts Unknown      NaN
# 6225                                      Frasier      NaN
# 6226                          La Familia P. Luche      NaN
# 6227                 The Adventures of Figaro Pho      NaN
# 6228                                     Kikoriki      NaN
# 6229                                 Red vs. Blue      NaN
# 6230                                        Maron      NaN
# 6231       Little Baby Bum: Nursery Rhyme Friends      NaN
# ...

# %%
#Dropping duplicates
df = df.append(df)
df.shape
# Out:
# (7548, 12)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (3774, 12)

# %%
df = df.append(df)
df.drop_duplicates(inplace=True, keep=False)
df.shape
# Out:
# (0, 12)

# %%
#Finding Null Values
df = pd.read_csv('data/netflix_titles.csv')
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df = df.dropna()
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# 6       False  False  False     False  False    False       False
# 7       False  False  False     False  False    False       False
# 9       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6142    False  False  False     False  False    False       False
# 6158    False  False  False     False  False    False       False
# 6167    False  False  False     False  False    False       False
# 6182    False  False  False     False  False    False       False
# 6213    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df1 = pd.DataFrame({'id':[1,2,3,4,5],
                   'Name':['Boltzmann','Cherenkov','Dirac', 'Einstein','Feynman'],
                   'subject_id':['sub1', 'sub2', 'sub4', 'sub6', 'sub5']})

df2 = pd.DataFrame({'id':[1,2,3,4,5],
                   'Name':['Lorenz','Maxwell', 'Newton', 'Ohm', 'Planck'],
                   'subject_id':['sub2', 'sub4', 'sub3', 'sub6', 'sub5']})

# %%
#Merge two Dataframes on a Key
pd.merge(df1, df2, on='id')
# Out:
#    id     Name_x subject_id_x   Name_y subject_id_y
# 0   1  Boltzmann         sub1   Lorenz         sub2
# 1   2  Cherenkov         sub2  Maxwell         sub4
# 2   3      Dirac         sub4   Newton         sub3
# 3   4   Einstein         sub6      Ohm         sub6
# 4   5    Feynman         sub5   Planck         sub5

# %%
#Merge two Dataframes on Multiple Keys
pd.merge(df1, df2, on=['id','subject_id'])
# Out:
#    id    Name_x subject_id  Name_y
# 0   4  Einstein       sub6     Ohm
# 1   5   Feynman       sub5  Planck

# %%
#Left Join Using "How" Argument
pd.merge(df1, df2, on='subject_id', how='left')
# Out:
#    id_x     Name_x subject_id  id_y   Name_y
# 0     1  Boltzmann       sub1   NaN      NaN
# 1     2  Cherenkov       sub2   1.0   Lorenz
# 2     3      Dirac       sub4   2.0  Maxwell
# 3     4   Einstein       sub6   4.0      Ohm
# 4     5    Feynman       sub5   5.0   Planck

# %%
#Right Join using "How" Argument
pd.merge(df1, df2, on='subject_id', how='right')
# Out:
#    id_x     Name_x subject_id  id_y   Name_y
# 0   2.0  Cherenkov       sub2     1   Lorenz
# 1   3.0      Dirac       sub4     2  Maxwell
# 2   4.0   Einstein       sub6     4      Ohm
# 3   5.0    Feynman       sub5     5   Planck
# 4   NaN        NaN       sub3     3   Newton

# %%
#Outer Join using "How" Argument
pd.merge(df1, df2, on='subject_id', how='outer')
# Out:
#    id_x     Name_x subject_id  id_y   Name_y
# 0   1.0  Boltzmann       sub1   NaN      NaN
# 1   2.0  Cherenkov       sub2   1.0   Lorenz
# 2   3.0      Dirac       sub4   2.0  Maxwell
# 3   4.0   Einstein       sub6   4.0      Ohm
# 4   5.0    Feynman       sub5   5.0   Planck
# 5   NaN        NaN       sub3   3.0   Newton

# %%
#Inner Join using "How" Argument
pd.merge(df1, df2, on='subject_id', how='inner')
# Out:
#    id_x     Name_x subject_id  id_y   Name_y
# 0     2  Cherenkov       sub2     1   Lorenz
# 1     3      Dirac       sub4     2  Maxwell
# 2     4   Einstein       sub6     4      Ohm
# 3     5    Feynman       sub5     5   Planck

# %%
# Getting info about your data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 0 to 6213
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3774 non-null   int64
#  1   type          3774 non-null   object
#  2   title         3774 non-null   object
#  3   director      3774 non-null   object
#  4   cast          3774 non-null   object
#  5   country       3774 non-null   object
#  6   date_added    3774 non-null   object
#  7   release_year  3774 non-null   int64
#  8   rating        3774 non-null   object
#  9   duration      3774 non-null   object
#  10  listed_in     3774 non-null   object
#  11  description   3774 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 383.3+ KB

# %%
#Replace Value Anywhere
import pandas as pd
df = pd.DataFrame({
    'name': ['daniel', 'lisa', 'anthony'],
    'age':[24, 43, 31],
    'city':['london', 'paris', 'sydney']
})
df
# Out:
#       name  age    city
# 0   daniel   24  london
# 1     lisa   43   paris
# 2  anthony   31  sydney

# %%
df.replace([24], 40)
# Out:
#       name  age    city
# 0   daniel   40  london
# 1     lisa   43   paris
# 2  anthony   31  sydney

# %%
#Replace with Dict
df.replace({
    31:38,
    'daniel':'daniella'
})
# Out:
#        name  age    city
# 0  daniella   24  london
# 1      lisa   43   paris
# 2   anthony   38  sydney

# %%
#Replace with Regex
df.replace('li.+','ANON', regex=True)
# Out:
#       name  age    city
# 0   daniel   24  london
# 1     ANON   43   paris
# 2  anthony   31  sydney

# %%
#Replace in single column
df = pd.DataFrame({
    'name':['daniel', 'lisa', 'anthony'],
    'num_pets':[0, 1, 3],
    'num_children': [4, 3, 0]
})

#Replace 0 with 1 in column 'num_children' only
df.replace({'num_children':{0:1}})
# Out:
#       name  num_pets  num_children
# 0   daniel         0             4
# 1     lisa         1             3
# 2  anthony         3             1

# %%
#Get Gapminder Dataset
url = 'http://bit.ly/2cLzoxH'
data = pd.read_csv(url)
data.head(3)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %%
# Select two columns from dataframe
df = data[['continent','gdpPercap']]
df.shape
# Out:
# (1704, 2)

# %%
# Example of pivot_table
pd.pivot_table(df, values='gdpPercap',
              columns='continent')
# Out:
# continent       Africa     Americas         Asia        Europe       Oceania
# gdpPercap  2193.754578  7136.110356  7902.150428  14469.475533  18621.609223

# %%
# Pivot table with three columns from dataframe
df1 = data[['continent', 'year', 'gdpPercap']]
pd.pivot_table(df1, values='gdpPercap',
              index=['year'],
              columns='continent')
# Out:
# continent       Africa      Americas          Asia        Europe       Oceania
# year
# 1952       1252.572466   4079.062552   5195.484004   5661.057435  10298.085650
# 1957       1385.236062   4616.043733   5787.732940   6963.012816  11598.522455
# 1962       1598.078825   4901.541870   5729.369625   8365.486814  12696.452430
# 1967       2050.363801   5668.253496   5971.173374  10143.823757  14495.021790
# 1972       2339.615674   6491.334139   8187.468699  12479.575246  16417.333380
# 1977       2585.938508   7352.007126   7791.314020  14283.979110  17283.957605
# 1982       2481.592960   7506.737088   7434.135157  15617.896551  18554.709840
# 1987       2282.668991   7793.400261   7608.226508  17214.310727  20448.040160
# 1992       2281.810333   8044.934406   8639.690248  17061.568084  20894.045885
# 1997       2378.759555   8889.300863   9834.093295  19076.781802  24024.175170
# 2002       2599.385159   9287.677107  10174.090397  21711.732422  26938.778040
# ...

# %%
# Pivot_table with Different Aggregating Functions
pd.pivot_table(df1, values='gdpPercap',
              index=['year'],
              columns='continent',
              aggfunc='min')
# Out:
# continent      Africa     Americas   Asia       Europe      Oceania
# year
# 1952       298.846212  1397.717137  331.0   973.533195  10039.59564
# 1957       335.997115  1544.402995  350.0  1353.989176  10949.64959
# 1962       355.203227  1662.137359  388.0  1709.683679  12217.22686
# 1967       412.977514  1452.057666  349.0  2172.352423  14463.91893
# 1972       464.099504  1654.456946  357.0  2860.169750  16046.03728
# 1977       502.319733  1874.298931  371.0  3528.481305  16233.71770
# 1982       462.211415  2011.159549  424.0  3630.880722  17632.41040
# 1987       389.876185  1823.015995  385.0  3738.932735  19007.19129
# 1992       410.896824  1456.309517  347.0  2497.437901  18363.32494
# 1997       312.188423  1341.726931  415.0  3193.054604  21050.41377
# 2002       241.165877  1270.364932  611.0  4604.211737  23189.80135
# 2007       277.551859  1201.637154  944.0  5937.029526  25185.00911

# %%
# Pivot table with Min and Max Aggregate Functions
pd.pivot_table(df1, values='gdpPercap',
              index=['year'],
              columns='continent',
              aggfunc=[min,max])
# Out:
#                   min                                                \
# continent      Africa     Americas   Asia       Europe      Oceania
# year
# 1952       298.846212  1397.717137  331.0   973.533195  10039.59564
# 1957       335.997115  1544.402995  350.0  1353.989176  10949.64959
# 1962       355.203227  1662.137359  388.0  1709.683679  12217.22686
# 1967       412.977514  1452.057666  349.0  2172.352423  14463.91893
# 1972       464.099504  1654.456946  357.0  2860.169750  16046.03728
# 1977       502.319733  1874.298931  371.0  3528.481305  16233.71770
# 1982       462.211415  2011.159549  424.0  3630.880722  17632.41040
# 1987       389.876185  1823.015995  385.0  3738.932735  19007.19129
# 1992       410.896824  1456.309517  347.0  2497.437901  18363.32494
# 1997       312.188423  1341.726931  415.0  3193.054604  21050.41377
# 2002       241.165877  1270.364932  611.0  4604.211737  23189.80135
# 2007       277.551859  1201.637154  944.0  5937.029526  25185.00911
#
# ...

# %%
#Read from CSV
df = pd.read_csv('data/netflix_titles.csv')

# %%
#Print columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Rename columns
df.rename(columns={'release_year': 'Release Year'}, inplace=True)
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'Release Year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Lowercase Columns
df.columns = [col.lower() for col in df]
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Extract Column to Series
df = df.dropna()
directors = df['director']
print(directors.head(10), '\n\n', type(directors))
# Out:
# 0            Richard Finn, Tim Maltby
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# 9                   Henrik Ruben Genz
# 10              José Miguel Contreras
# 11                   Daniel Alfredson
# 13        Munjal Shroff, Tilak Shetty
# 14        Munjal Shroff, Tilak Shetty
# 15                       Tilak Shetty
# Name: director, dtype: object
#
#  <class 'pandas.core.series.Series'>

# %%
#Extract Column to DataFrame
directors = df[['director']]
print(directors.head(10), '\n\n', type(directors))
# Out:
# Empty DataFrame
# Columns: [director]
# Index: []
#
#  <class 'pandas.core.frame.DataFrame'>

# %%
#Extract Row Using loc
df = pd.read_csv('data/netflix_titles.csv', index_col='title')
df = df.dropna()
df.loc['Automata']
# Out:
# show_id                                                  70304989
# type                                                        Movie
# director                                              Gabe Ibáñez
# cast            Antonio Banderas, Dylan McDermott, Melanie Gri...
# country                    Bulgaria, United States, Spain, Canada
# date_added                                      September 8, 2017
# release_year                                                 2014
# rating                                                          R
# duration                                                  110 min
# listed_in       International Movies, Sci-Fi & Fantasy, Thrillers
# description     In a dystopian future, an insurance adjuster f...
# Name: Automata, dtype: object

# %%
#Extract Row using iloc
df.iloc[2]
# Out:
# show_id                                                  70304989
# type                                                        Movie
# director                                              Gabe Ibáñez
# cast            Antonio Banderas, Dylan McDermott, Melanie Gri...
# country                    Bulgaria, United States, Spain, Canada
# date_added                                      September 8, 2017
# release_year                                                 2014
# rating                                                          R
# duration                                                  110 min
# listed_in       International Movies, Sci-Fi & Fantasy, Thrillers
# description     In a dystopian future, an insurance adjuster f...
# Name: Automata, dtype: object

# %%
#Slicing DataFrame using loc
film_collection = df.loc['#realityhigh':'Good People']
film_collection
# Out:
#                                      show_id   type  \
# title
# #realityhigh                        80125979  Movie
# Automata                            70304989  Movie
# Fabrizio Copano: Solo pienso en mi  80164077  Movie
# Good People                         70304990  Movie
#
#                                                            director  \
# title
# #realityhigh                                       Fernando Lebrija
# Automata                                                Gabe Ibáñez
# Fabrizio Copano: Solo pienso en mi  Rodrigo Toro, Francisco Schultz
# Good People                                       Henrik Ruben Genz
#
#                                                                                  cast  \
# title
# #realityhigh                        Nesta Cooper, Kate Walsh, John Michael Higgins...
# Automata                            Antonio Banderas, Dylan McDermott, Melanie Gri...
# ...

# %%
#Slicing DataFrame using iloc
film_collection = df.iloc[1:5]
film_collection
# Out:
#                                      show_id   type  \
# title
# #realityhigh                        80125979  Movie
# Automata                            70304989  Movie
# Fabrizio Copano: Solo pienso en mi  80164077  Movie
# Good People                         70304990  Movie
#
#                                                            director  \
# title
# #realityhigh                                       Fernando Lebrija
# Automata                                                Gabe Ibáñez
# Fabrizio Copano: Solo pienso en mi  Rodrigo Toro, Francisco Schultz
# Good People                                       Henrik Ruben Genz
#
#                                                                                  cast  \
# title
# #realityhigh                        Nesta Cooper, Kate Walsh, John Michael Higgins...
# Automata                            Antonio Banderas, Dylan McDermott, Melanie Gri...
# ...

# %%
#Conditional Selection
spielberg = df[df['director'] == 'Steven Spielberg']
spielberg.head(5)
# Out:
#                                                      show_id   type  \
# title
# The Adventures of Tintin                            70121502  Movie
# War Horse                                           70172928  Movie
# Catch Me If You Can                                 60024942  Movie
# Indiana Jones and the Kingdom of the Crystal Skull  70084799  Movie
# Indiana Jones and the Last Crusade                  60010487  Movie
#
#                                                             director  \
# title
# The Adventures of Tintin                            Steven Spielberg
# War Horse                                           Steven Spielberg
# Catch Me If You Can                                 Steven Spielberg
# Indiana Jones and the Kingdom of the Crystal Skull  Steven Spielberg
# Indiana Jones and the Last Crusade                  Steven Spielberg
#
#                                                                                                  cast  \
# title
# ...

# %%
#Conditional Selection Using Numerical Values
df = pd.read_csv('data/netflix_titles.csv', index_col='title')
films = df[df['type'] == 'Movie']
films['duration']= films['duration'].str.replace(' min', '')
films['duration'] = pd.to_numeric(films['duration'], errors ='coerce')
films[films['duration'] >= 180].head(5)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                         show_id   type            director  \
# title
# King of Boys           81172721  Movie        Kemi Adetiba
# The Gospel of Luke     81035749  Movie         David Batty
# ...

# %%
#Find N/A value 
df = pd.read_csv("data/netflix_titles.csv", index_col='title')
df = df.loc['Transformers: Robots in Disguise'].fillna("David Hartman, Vinton Heuck, Scooter Tidwell, Frank Marino,Todd Waterman")
df
# Out:
# show_id                                                  80058654
# type                                                      TV Show
# director        David Hartman, Vinton Heuck, Scooter Tidwell, ...
# cast            Will Friedle, Darren Criss, Constance Zimmer, ...
# country                                             United States
# date_added                                      September 8, 2018
# release_year                                                 2016
# rating                                                      TV-Y7
# duration                                                 1 Season
# listed_in                                                Kids' TV
# description     When a prison ship crash unleashes hundreds of...
# Name: Transformers: Robots in Disguise, dtype: object

# %%
#Using groupby and lambda function
#Finding Null Values
df = pd.read_csv('data/netflix_titles.csv')
top_countries = df.groupby('country')['title'].count().sort_values().index
df['country'] = df.country.apply(lambda x: 'Others' if (x not in top_countries[-20:]) else x)
df['country'].nunique()
# Out:
# 21

# %%
#Pivoting
df = pd.read_csv('data/netflix_titles.csv')
df_pivot = pd.pivot_table(df, index=["director","country","type"])
df_pivot
# Out:
#                                                     release_year       show_id
# director            country                  type
# A. L. Vijay         India                    Movie   2017.500000  8.065309e+07
# A. Salaam           India                    Movie   1975.000000  8.015848e+07
# A.R. Murugadoss     India                    Movie   2017.666667  8.105465e+07
# Aadish Keluskar     India                    Movie   2018.000000  8.107437e+07
# Aamir Bashir        India                    Movie   2010.000000  7.015355e+07
# ...                                                          ...           ...
# Çagan Irmak         Turkey                   Movie   2005.000000  8.023107e+07
# Ísold Uggadóttir    Iceland, Sweden, Belgium Movie   2018.000000  8.099843e+07
# Óskar Thór Axelsson Iceland                  Movie   2017.000000  8.021699e+07
# Ömer Faruk Sorak    Turkey                   Movie   2007.500000  8.013278e+07
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
subset = df[['type', 'rating']]
subset.head()

# %%
cast_col = df['cast']
cast_col.head()

# %%
#Replace values

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,10))
sns.set(style='darkgrid')
ax = sns.countplot(x='rating', data= df, palette="Set2", order=df['rating'].value_counts().index[0:15])

# %%
import plotly.express as px
import pandas as pd

# %%
imdb_ratings = pd.read_csv('data/IMDb ratings.csv', usecols=['weighted_average_vote'])
imdb_titles = pd.read_csv('data/IMDb movies.csv', usecols=['title', 'year', 'genre'])
netflix_overall = pd.read_csv('data/netflix_titles.csv')
netflix_overall.dropna()
ratings = pd.DataFrame({'Title':imdb_titles.title,
                    'Release Year':imdb_titles.year,
                    'Rating': imdb_ratings.weighted_average_vote,
                    'Genre':imdb_titles.genre})

ratings.drop_duplicates(subset=['Title','Release Year','Rating'], inplace=True)
ratings.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning:
#
# Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
# (85852, 4)

# %%
ratings.dropna()
merged = ratings.merge(netflix_overall, left_on='Title', right_on='title', 
                      how='inner')
merged = merged.sort_values(by='Rating', ascending=False)

# %%
top_rated = merged[0:10]
fig = px.sunburst(top_rated,
                 path=['title', 'country'],
                 values='Rating',
                 color='Rating')
fig.show()
# Out:
# <div>
#
#
#             <div id="23ec7cc2-35a0-4ed0-8a57-79ddfed28f5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23ec7cc2-35a0-4ed0-8a57-79ddfed28f5c")) {
#                     Plotly.newPlot(
#                         '23ec7cc2-35a0-4ed0-8a57-79ddfed28f5c',
# ...
